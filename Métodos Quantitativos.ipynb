# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('Dados-Pesquisa.xlsx')

# %%
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
df.dtypes
# Out:
# Age                     float64
# AttendedBootcamp        float64
# BootcampFinish          float64
# BootcampFullJobAfter    float64
# BootcampLoanYesNo       float64
#                          ...
# ResourceW3Schools       float64
# ResourceYouTube         float64
# SchoolDegree             object
# SchoolMajor              object
# StudentDebtOwe          float64
# Length: 113, dtype: object

# %%
df.isnull().sum()
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
display(df)
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# ...

# %%
sum_age = df["Age"].sum()

# %%
print(sum_age)
# Out:
# 397165.0

# %%
i=0
for item in df["Age"]:
   i=i+1

# %%
print("Media das idades",sum_age /i)
# Out:
# Media das idades 25.426696542893726

# %%
print(i)
# Out:
# 15620

# %%
df.Age.hist(bins=100)
plt.xlabel("Idade")
plt.ylabel("Numero de Programadores")
plt.title("idade vc numéro de programadores")
plt.show()

# %%
df.CodeEventDjangoGirls.hist(bins=50)
plt.xlabel("número de garotas")
plt.ylabel("programadoras em Django")
plt.title("panorama de mulheres que programam no Django")
plt.show()

# %%
a =0
for item in df["CountryCitizen"]:
   if (item == "Brazil"):
    a=a+1

# %%
print("O número de Braileiros ",a)
# Out:
# O número de Braileiros  299

# %%
# Out:
# porcentagem de Brasileiros 1.0

# %%
i=0
for item in df["Age"]:
    i+=1

# %%
print(i)
# Out:
# 15620

# %%
print("porcentagem de Brasileiros",(a/i)*100,"%")
# Out:
# porcentagem de Brasileiros 1.914212548015365 %
