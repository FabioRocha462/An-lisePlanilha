# %%
import pandas as pd 
import sweetviz as sv 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Dados-Pesquisa.xlsx")

# %%
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
df["ResourceW3Schools"].isnull().sum()
# Out:
# 15499

# %%
i=0 
for item in df["ResourceUdemy"]:
    if(item==1):
        i+=1

# %%
print(i)
# Out:
# 4130

# %%
df["ResourceYouTube"].isnull().sum()
# Out:
# 15499

# %%
df["ResourceYouTube"].sum()
# Out:
# 121.0

# %%
df.HasDebt.hist(bins=100)
plt.xlabel("valor")
plt.ylabel("Numero de Programadores")
plt.title("valor vs numéro de programadores")
plt.show()

# %%
i=0
for item in df["LanguageAtHome"]:
    if(item=="Portuguese"):
        i+=1

# %%
print(i)
# Out:
# 394

# %%
df.LanguageAtHome.hist(bins=1000)
plt.xlabel("lingua dos programadores")
plt.ylabel("quantidade")
plt.title("idioma dos programadores")
plt.show()

# %%
df.MonthsProgramming.hist(bins=60)
plt.xlabel("Meses programando")
plt.ylabel("quantidade")
plt.title("total de meses programando")
plt.show()

# %%
df.MaritalStatus.hist(bins=40)
plt.xlabel("Estado Civil")
plt.ylabel("quantidade")
plt.title("Estado civil")
plt.show()

# %%
df.HoursLearning.hist(bins=60)
plt.xlabel("horas aprendendo")
plt.ylabel("quantidade")
plt.title("quantidade de horas usadas para estudo")
plt.show()

# %%
df.MoneyForLearning.hist(bins=40)
plt.xlabel("dinheiro investido no aprendizado")
plt.ylabel("quantidade de programadores")
plt.title("quantidade de dinheiro para estudo")
plt.show()
